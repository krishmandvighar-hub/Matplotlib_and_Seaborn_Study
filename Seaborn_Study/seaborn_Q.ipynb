# %%
# Beginner Level Seaborn Questions
# 1.Load the tips dataset using Seaborn and display first 10 rows.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

tips=sns.load_dataset("tips")
print(tips.head(10))

# 2.Find:
#    columns or total rows
#    datatype of each column.
print(tips.shape)
print(tips.dtypes)

# 3.Create a scatterplot between:
#      total_bill and tip.
tips=sns.load_dataset("tips")
sns.scatterplot(x="total_bill",y="tip",hue="day",data=tips)
plt.show()

# 4.Create a histogram of total_bill.
sns.histplot(tips["total_bill"],kde=True)
plt.show()

# 5.Create a countplot for day.
sns.countplot(x="day",data=tips)
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2
# (244, 7)
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# 6.Create a boxplot of total_bill by sex.
sns.boxplot(x="sex",y="total_bill",data=tips)
plt.show()

# 7.Create a violinplot of tip by day.
sns.violinplot(x="day",y="total_bill",data=tips)
plt.show()

# 8.Show relationship between:
#    size and tip using lmplot().
sns.lmplot(x="size",y="tip",data=tips)
plt.show()

# 9.Create a pairplot of the iris dataset.
iris=sns.load_dataset("iris")
sns.pairplot(iris,hue="species")
plt.show()

# 10.Create a heatmap using correlation matrix of tips dataset.
corr=tips.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.show()

#--------------------------- Intermediate Level Questions-------------------------------
#11. In tips dataset:
# Which day has highest average tip?
avr_tip=tips.groupby("day")["tip"].mean()
print(avr_tip.sort_values().head(1))
# Out:
# day
# Fri    2.734737
# Name: tip, dtype: float64
# C:\Users\Webtech\AppData\Local\Temp\ipykernel_9736\926448050.py:27: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avr_tip=tips.groupby("day")["tip"].mean()

# %%
# Out:
# day
# Fri    2.734737
# Name: tip, dtype: float64
# C:\Users\Webtech\AppData\Local\Temp\ipykernel_9736\2078924951.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avr_tip=tips.groupby("day")["tip"].mean()

# %%
#12. Create a barplot showing:
# average total_bill per day.
sns.barplot(x="day",y="total_bill",data=tips)
plt.show()

#13. Create a grouped boxplot:
# total_bill by day and smoker.
sns.boxplot(x="day",y="total_bill",data=tips)
plt.show()

#14. Create a heatmap with annotations for correlations.
corr=tips.corr(numeric_only=True)
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.show()

#15. Use hue parameter in scatterplot:
# total_bill vs tip
# color by sex.
tips=sns.load_dataset("tips")
sns.scatterplot(x="total_bill",y="tip",hue="sex",data=tips)
plt.show()

#16. Create a KDE plot for total_bill.
sns.kdeplot(x="total_bill", data=tips)
plt.show()

#17.Compare distributions of male and female tips using histplot()
sns.histplot(tips["sex"])
plt.show()

# %%
#18. Create subplots:
# histogram
# boxplot
# scatterplot
# in one figure.

plt.figure(figsize=(18,12))
plt.subplot(2,2,1)
sns.kdeplot(x="total_bill", data=tips,color="k")

plt.subplot(2,2,2)
sns.violinplot(x="day",y="total_bill",data=tips,color="c")


plt.subplot(2,2,3)
sns.boxplot(x="sex",y="total_bill",data=tips,color="red")


plt.subplot(2,2,4)

sns.histplot(tips["sex"],color="g")
plt.show()

# %%
#19. Find outliers in tips dataset visually using boxplot.
sns.boxplot(y="total_bill",data=tips,color="red")
plt.show()
#20. Create a lineplot using fmri dataset:
# x = timepoint
# y = signal
# hue = event.
fmri=sns.load_dataset("fmri")
sns.lineplot(x="timepoint",y="signal",hue="region",data=fmri)
plt.show()

# %%
# Advanced Level Questions
#21. Create a dashboard using multiple Seaborn charts.
import seaborn as sns
import matplotlib.pyplot as plt
# Load dataset
df = sns.load_dataset("tips")
plt.figure(figsize=(10,8))

plt.subplot(2,2,1)
sns.histplot(df["total_bill"])

plt.subplot(2,2,2)
sns.boxplot(y="tip", data=df)

plt.subplot(2,2,3)
sns.scatterplot(x="total_bill", y="tip", data=df)

plt.subplot(2,2,4)
sns.countplot(x="day", data=df)

plt.tight_layout()
plt.show()

# %%
#22. Analyze penguins dataset:
# species-wise body mass comparison.
penguins = sns.load_dataset("penguins")

sns.boxplot(x="species", y="body_mass_g", data=penguins)

plt.show()

#23. Create a FacetGrid:
# separate histograms by sex.
# Load dataset
df = sns.load_dataset("tips")

g = sns.FacetGrid(df, col="sex")
g.map(sns.histplot, "total_bill")

plt.show()

#24. Use catplot() for:
# average bill by day.
sns.catplot(x="day", y="total_bill", kind="bar", data=df)

plt.show()
#25. Create a jointplot between:
# total_bill and tip.
sns.jointplot(x="total_bill", y="tip", data=df)

plt.show()

# %%
#26. Create a clustermap using correlation matrix.
# Load dataset
df = sns.load_dataset("tips")

# Correlation matrix
corr = df.corr(numeric_only=True)

# Clustermap
sns.heatmap(corr, annot=True)

plt.show()

#27. Compare smokers vs non-smokers spending patterns.

sns.boxplot(x="smoker", y="total_bill", data=df)

plt.show()
#28. Create regression plots for:
# size vs total_bill.
sns.regplot(x="size", y="total_bill", data=df)

plt.show()
#29. Build a visualization report for iris dataset using:
# pairplot
# heatmap
# boxplot
# violinplot.
iris = sns.load_dataset("iris")

sns.pairplot(iris)
plt.show()

corr = iris.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.show()

sns.boxplot(data=iris)
plt.show()

sns.violinplot(x="species", y="sepal_length", data=iris)
plt.show()
